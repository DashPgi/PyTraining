# %%
import pandas as pd

data = pd.read_csv("employees_dirty.csv")

data
# Out:
#     employee_id             name    age  gender    department salary  \
# 0          1001       Ali Ahmadi   24.0    Male            IT   1800
# 1          1002   Sara Mohammadi   29.0  Female  Data Science   2500
# 2          1003      Reza Karimi   31.0    Male        DevOps   3200
# 3          1004  Maryam Hosseini    NaN  Female            IT   2100
# 4          1005       John Smith   45.0    Male    Management   5200
# 5          1006      Amir Rezaei   27.0    male  Data Science   2400
# 6          1007       Nina Weber   34.0  Female            HR    NaN
# 7          1008       Hassan Ali   22.0    Male            IT   1700
# 8          1009      Lisa Muller   28.0       F        DevOps   2900
# 9          1010      David Brown   39.0    Male    Management   4800
# 10        10011       Ali Ahmadi   24.0    Male            IT   1800
# 11        10012   Sara Mohammadi   29.0  Female  Data Science   2500
# 12         1013     Mehdi Kazemi  200.0    Male            IT   2300
# ...

# %%
data[~data["gender"].isin(["Male", "Female"])]
# Out:
#    employee_id         name   age gender department salary  experience  \
# 8         1009  Lisa Muller  28.0      F     DevOps   2900         5.0
#
#       city   hire_date           email  performance_score
# 8  Hamburg  2021-04-18  lisa@gmail.com               89.0
